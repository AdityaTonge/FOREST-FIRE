# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
for i in df.columns:
    df.rename({i:i.strip()},inplace=True,axis=1)

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        nan, 'Classes  ', 'not fire     ', 'not fire    '], dtype=object)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# Classes            1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df[df['Classes']=='Classes  ']
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI    Classes
# 123  FWI  Classes

# %%
df.drop(123,inplace=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.reset_index()
# Out:
#      index day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  \
# 0        0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1        1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2        2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3        3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4        4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2
# ..     ...  ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...
# 240    241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5
# 241    242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1
# 242    243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4
# 243    244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7
# 244    245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI       Classes
# 0     3.4  0.5   not fire
# 1     3.9  0.4   not fire
# 2     2.7  0.1   not fire
# 3     1.7    0   not fire
# 4     3.9  0.5   not fire
# ..    ...  ...           ...
# 240  16.9  6.5       fire
# 241   6.2    0   not fire
# 242   3.4  0.2   not fire
# 243   5.1  0.7   not fire
# 244   4.8  0.5  not fire
#
# [245 rows x 15 columns]

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        nan, 'not fire     ', 'not fire    '], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
# dtypes: object(14)
# memory usage: 28.7+ KB

# %%
df[df['Classes'].isnull()]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 167                             14    07  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN     NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire        NaN

# %%
df.drop(122,inplace=True)

# %%
df['Classes'][167]='fire'

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
def target_encode(s):
    if 'not' in s:
        return 0
    else:
        return 1

# %%
df['Classes'] = df['Classes'].apply(target_encode)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#    Classes
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    int64
# dtypes: int64(1), object(13)
# memory usage: 36.7+ KB

# %%
integer = ['day','month','year','Temperature','RH','Ws']

# %%
floats = ['FFMC','DMC','DC','ISI','BUI','FWI']

# %%
for i in integer:
    df[i] = df[i].astype(int)

# %%
df['FFMC'] = df['FFMC'].astype(float)
df['DMC'] = df['DMC'].astype(float)
df['ISI'] = df['ISI'].astype(float)
df['BUI'] = df['BUI'].astype(float)
df['FWI'] = df['FWI'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 5
#       3 df['ISI'] = df['ISI'].astype(float)
#       4 df['BUI'] = df['BUI'].astype(float)
# ----> 5 df['FWI'] = df['FWI'].astype(float)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'fire   '

# %%
df['DC'] = df['DC'].astype(float)
df['FWI'] = df['FWI'].astype(float)

# %%
df.info()

# %%
df.head()

# %%
df['Rain'] = df['Rain'].astype(float)

# %%
df[df['DC']=='14.6 9']
df['DC'][167]='14.69'
# Out:
# C:\Users\abcd\AppData\Local\Temp\ipykernel_13348\2781298097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DC'][167]='14.69'

# %%
df['FWI'] = df['FWI'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df['FWI'] = df['FWI'].astype(float)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'fire   '

# %%
df[df['FWI']=='fire   ']
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI  \
# 167   14      7  2012           37  37  18   0.2  88.9  12.9  14.69  12.5
#
#       BUI      FWI  Classes
# 167  10.4  fire           1

# %%
df['FWI'][167]=df.drop(167)['FWI'].astype(float).median()
# Out:
# C:\Users\abcd\AppData\Local\Temp\ipykernel_13348\4148343334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FWI'][167]=df.drop(167)['FWI'].astype(float).median()

# %%
df.head(20)
# Out:
#     day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0     1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1     2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2     3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3     4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4     5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# 5     6      6  2012           31  67  14   0.0  82.6   5.8  22.2  3.1   7.0
# 6     7      6  2012           33  54  13   0.0  88.2   9.9  30.5  6.4  10.9
# 7     8      6  2012           30  73  15   0.0  86.6  12.1  38.3  5.6  13.5
#
#       BUI   FWI  Classes
# 226   6.6   1.2        0
# 227   9.1   3.9        1
# 228  12.4  10.3        1
# 229  14.3   5.7        1
# 230  17.8   9.8        1
# 231  22.4  19.3        1
# 232  26.2  17.5        1
# 233  28.2  15.4        1
# 234  28.9   5.6        1
# 235  24.4   3.8        0
# 236  29.4  21.6        1
# 237  32.4  13.7        1
# 238  36.0  15.2        1
# 239  11.9   0.4        0
# 240  14.1     3        0
# 241  16.9   6.5        1
# 242   6.2     0        0
# 243   3.4   0.2        0
# 244   5.1   0.7        0
# 245   4.8   0.5        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int32
#  1   month        244 non-null    int32
#  2   year         244 non-null    int32
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    int64
# dtypes: float64(5), int32(6), int64(1), object(2)
# memory usage: 31.0+ KB

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5     8  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes
# 0    0.5        0
# 1    0.4        0
# 2    0.1        0
# 3      0        0
# 4    0.5        0
# ..   ...      ...
# 241  6.5        1
# 242    0        0
# 243  0.2        0
# 244  0.7        0
# 245  0.5        0
#
# [244 rows x 14 columns]

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7    0        0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    object
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      244 non-null    int64
# dtypes: float64(6), int32(3), int64(1), object(1)
# memory usage: 28.1+ KB

# %%
df['FWI']=df['FWI'].astype(float)

# %%
df['DC'] = df['DC'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 245
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      244 non-null    int64
# dtypes: float64(7), int32(3), int64(1)
# memory usage: 28.1 KB

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
plt.style.use('default')
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
percenatages = df['Classes'].value_counts(normalize=True)*100

# %%
classlabels = ['Fire','Not Fire']
plt.figure(figsize=(3,3))
plt.pie(percenatages,labels = classlabels,autopct= '%1.1f%%')
plt.title('Classes PieChart')
plt.show()

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.654443 -0.278132 -0.326786  0.677491  0.483105
# RH             -0.654443  1.000000  0.236084  0.222968 -0.645658 -0.405133
# Ws             -0.278132  0.236084  1.000000  0.170169 -0.163255 -0.001246
# Rain           -0.326786  0.222968  0.170169  1.000000 -0.544045 -0.288548
# FFMC            0.677491 -0.645658 -0.163255 -0.544045  1.000000  0.602391
# DMC             0.483105 -0.405133 -0.001246 -0.288548  0.602391  1.000000
# DC              0.370511 -0.220344  0.076253 -0.296808  0.503919  0.875362
# ISI             0.607551 -0.690637  0.015248 -0.347105  0.739730  0.674499
# BUI             0.455504 -0.348587  0.029756 -0.299171  0.589652  0.982073
# FWI             0.562344 -0.574773  0.030910 -0.323831  0.688876  0.875791
# Classes         0.518119 -0.435023 -0.066529 -0.379449  0.770114  0.584188
#
#                    DC       ISI       BUI       FWI   Classes
# Temperature  0.370511  0.607551  0.455504  0.562344  0.518119
# RH          -0.220344 -0.690637 -0.348587 -0.574773 -0.435023
# Ws           0.076253  0.015248  0.029756  0.030910 -0.066529
# Rain        -0.296808 -0.347105 -0.299171 -0.323831 -0.379449
# FFMC         0.503919  0.739730  0.589652  0.688876  0.770114
# DMC          0.875362  0.674499  0.982073  0.875791  0.584188
# DC           1.000000  0.498926  0.941906  0.739634  0.507132
# ISI          0.498926  1.000000  0.635891  0.913163  0.735511
# BUI          0.941906  0.635891  1.000000  0.858065  0.583882
# FWI          0.739634  0.913163  0.858065  1.000000  0.716490
# Classes      0.507132  0.735511  0.583882  0.716490  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df,color='green')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
y = df['FWI']
X = df.drop('FWI',axis=1)

# %%
#train_test_split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (183, 10)

# %%
X_test.shape
# Out:
# (61, 10)

# %%
#feature Selection Based on correlation
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.664492 -0.249312 -0.375047  0.703238  0.485379
# RH             -0.664492  1.000000  0.235766  0.262550 -0.637201 -0.398168
# Ws             -0.249312  0.235766  1.000000  0.262759 -0.169489 -0.013533
# Rain           -0.375047  0.262550  0.262759  1.000000 -0.585018 -0.291338
# FFMC            0.703238 -0.637201 -0.169489 -0.585018  1.000000  0.602278
# DMC             0.485379 -0.398168 -0.013533 -0.291338  0.602278  1.000000
# DC              0.374689 -0.215094  0.073933 -0.296119  0.508360  0.877050
# ISI             0.609525 -0.694976  0.015384 -0.353219  0.744270  0.652894
# BUI             0.458575 -0.344365  0.022529 -0.301347  0.592841  0.981876
# Classes         0.512818 -0.429397 -0.078171 -0.394262  0.774398  0.580530
#
#                    DC       ISI       BUI   Classes
# Temperature  0.374689  0.609525  0.458575  0.512818
# RH          -0.215094 -0.694976 -0.344365 -0.429397
# Ws           0.073933  0.015384  0.022529 -0.078171
# Rain        -0.296119 -0.353219 -0.301347 -0.394262
# FFMC         0.508360  0.744270  0.592841  0.774398
# DMC          0.877050  0.652894  0.981876  0.580530
# DC           1.000000  0.496586  0.941251  0.501292
# ISI          0.496586  1.000000  0.624038  0.744568
# BUI          0.941251  0.624038  1.000000  0.583094
# Classes      0.501292  0.744568  0.583094  1.000000

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
#threshold given by domain experty
corr_features = correlation(X_train,0.85)

# %%
#drop features according to correlation
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (183, 8)

# %%
X_test.shape
# Out:
# (61, 8)

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.81085018,  0.16311382,  1.29231566, ..., -0.73698402,
#         -0.773495  , -1.1098231 ],
#        [ 1.06405791, -0.44884168,  0.15167049, ...,  0.7287992 ,
#          0.83939993,  0.9010445 ],
#        [-0.27516216,  0.63907922, -0.60875963, ..., -0.51271118,
#         -0.21981465,  0.9010445 ],
#        ...,
#        [-1.88222624,  0.91105944,  0.53188555, ..., -1.07339329,
#         -1.08644476, -1.1098231 ],
#        [ 0.26052587, -0.38084663,  0.15167049, ...,  0.08000991,
#          0.47830405,  0.9010445 ],
#        [-0.54300617,  0.9790545 ,  2.05274578, ..., -1.02533482,
#         -0.86978723, -1.1098231 ]])

# %%
X_test_scaled
# Out:
# array([[-2.75162156e-01,  9.51187672e-02, -2.28544571e-01,
#         -3.81132246e-01,  6.38241722e-01, -4.01362602e-02,
#          2.37573464e-01,  9.01044498e-01],
#        [ 2.60525871e-01, -5.84831795e-01, -9.88974688e-01,
#         -3.81132246e-01,  7.42136256e-01, -3.84555270e-01,
#          4.06084874e-01,  9.01044498e-01],
#        [ 2.60525871e-01, -9.92802132e-01,  1.51670488e-01,
#         -3.81132246e-01,  7.00578442e-01, -5.44750158e-01,
#          5.02377108e-01,  9.01044498e-01],
#        [ 7.96213899e-01, -6.52826851e-01,  5.31885546e-01,
#         -1.47707879e-01,  1.88032075e-01,  4.80497126e-01,
#         -4.84618295e-01,  9.01044498e-01],
#        [ 2.13543397e+00, -1.46876753e+00, -2.12961986e+00,
#         -3.34447373e-01,  1.00533574e+00,  6.32682270e-01,
#          1.15234969e+00,  9.01044498e-01],
#        [ 1.86758995e+00,  9.51187672e-02, -2.50983492e+00,
#         -3.81132246e-01,  8.11399278e-01,  1.92146328e-01,
#          1.27271498e+00,  9.01044498e-01],
#        [-2.75162156e-01,  1.04704955e+00,  9.12100605e-01,
#         -3.81132246e-01,  5.75905001e-01,  2.47492348e+00,
#         -3.15712244e-03,  9.01044498e-01],
#        [ 1.06405791e+00, -2.28470820e+00,  9.12100605e-01,
#         -3.81132246e-01,  1.13693548e+00,  1.99433882e+00,
#          3.31892497e+00,  9.01044498e-01],
#        [-2.15007025e+00, -5.84831795e-01,  9.12100605e-01,
#         -3.34447373e-01,  1.53400563e-01, -8.33100956e-01,
#         -7.25348881e-01, -1.10982310e+00],
#        [-1.07869420e+00, -3.12851570e-01,  9.12100605e-01,
#          6.45934972e-01, -9.54807799e-01, -9.21208145e-01,
#         -8.45714174e-01, -1.10982310e+00],
#        [ 1.06405791e+00, -2.01272798e+00, -9.88974688e-01,
#         -3.34447373e-01,  9.08367510e-01,  8.88994091e-01,
#          1.03198440e+00,  9.01044498e-01],
#        [ 5.28369885e-01, -3.12851570e-01,  9.12100605e-01,
#         -3.81132246e-01,  7.28283651e-01, -8.81947267e-02,
#          7.91253812e-01,  9.01044498e-01]])

# %% [markdown]
# ## Boxplot to understand effect of scaling

# %%
plt.subplots(figsize=(15, 4))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linregressor = LinearRegression()
linregressor.fit(X_train_scaled,y_train)
y_pred = linregressor.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score= r2_score(y_test,y_pred)
print('Mean Absolute Error',mae)
print('R2 Score',score)
# Out:
# Mean Absolute Error 0.6713449860118946
# R2 Score 0.9863604990729762

# %% [markdown]
# # Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
linregressor.fit(X_train_scaled,y_train)
y_pred = linregressor.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score= r2_score(y_test,y_pred)
print('Mean Absolute Error',mae)
print('R2 Score',score)
# Out:
# Mean Absolute Error 1.9206880672466138
# R2 Score 0.8738776549773134

# %% [markdown]
# # Lasso Regression Model

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
linregressor.fit(X_train_scaled,y_train)
y_pred = linregressor.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score= r2_score(y_test,y_pred)
print('Mean Absolute Error',mae)
print('R2 Score',score)
# Out:
# Mean Absolute Error 1.9206880672466138
# R2 Score 0.8738776549773134

# %% [markdown]
# # ElasticNet Regression Model

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
Elasticnet = ElasticNet()
linregressor.fit(X_train_scaled,y_train)
y_pred = linregressor.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score= r2_score(y_test,y_pred)
print('Mean Absolute Error',mae)
print('R2 Score',score)
# Out:
# Mean Absolute Error 1.9206880672466138
# R2 Score 0.8738776549773134

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
